# %% [markdown]
# # Week 4 - Data Analysis

# %% [markdown]
# In order to carry out a linear regression analysis there are 3 steps
#
# 1. Create a scatter plot graph using two data sets
# 2. Draw the predictive line in the graph
# 3. Measure the fit of the data to the line
#
# Fortunately, Python has code modules to help.

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# The scatter plot gives a useful visualisation of the data but if the relationship between the data sets was perfect it would be a straight line.  So visualising the plots in relation to the ‘perfect’ line is useful
#
# The resultant graph shows the negative relationship between the plots and the line of regression.

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.title("Hours studied vs results")
plt.xlabel("Hours studied")
plt.ylabel("Result")
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# ### Tasks
#
# Given the following sets of numbers, calculate and output the mean and standard deviation rounded to two decimal places.
#
# x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
# y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
#
# An important aspect of learning new techniques is understanding how they can be effectively used.  Thinking of an industry you would like to work in make your notebook look like a report outlining the use of data.  For instance, make sure that you can label the scatter plot graph.

# %%
import numpy

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

meanX = numpy.mean(x)
meanY = numpy.mean(y)
standDevX = numpy.std(x)
standDevY = numpy.std(y)


print("Mean study time: " + "%0.2f" % meanX)
print("Mean grade: "  + "%0.2f" % meanY)
print("Standard Dev of study time: " + "%0.2f" % standDevX)
print("Standard Dev of grade: " + "%0.2f" % standDevY)

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.title("Hours studied vs results")
plt.xlabel("Hours studied")
plt.ylabel("Result")
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# Mean study time: 7.62
# Mean grade: 89.77
# Standard Dev of study time: 4.01
# Standard Dev of grade: 9.26
